# %%
import os
import numpy as np
import pandas as pd

# %%
a = pd.Series(["a","b","c","d","e"], index=[9,8,7,6,5])
a
# Out:
# 9    a
# 8    b
# 7    c
# 6    d
# 5    e
# dtype: object

# %%
b= np.array(["a","b","c","d","e"])
b
# Out:
# array(['a', 'b', 'c', 'd', 'e'], dtype='<U1')

# %%
b[0]
# Out:
# 'a'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ameli\\OneDrive\\Documents\\DataScience Python\\belajar_python\\data_science_II\\code'

# %%
os.chdir("C:\\Users\\ameli\\OneDrive\\Documents\\DataScience Python\\belajar_python\\data_science_II\\data\\input")

# %%
os.listdir()
# Out:
# ['bikesharing_data.csv',
#  'data1.xlsx',
#  'data_iris.csv',
#  'kaggle_survey_dataset_small.csv']

# %%
data = pd.read_excel("data1.xlsx")
data.index = range(12,25)

# %%
data
# Out:
#    gender  height  weight  shoes_size  score1  score2  score3
# 12      M     176      57          45       6       5       5
# 13      F     167      45          40       6       9       9
# 14      F     172      63          40       8      10       9
# 15      M     175      70          42      10       5       7
# 16      F     165      64          45       6      10       8
# 17      M     174      50          38       7       9       5
# 18      M     161      74          38       6       5       9
# 19      F     174      69          40       7       7       5
# 20      F     190      52          39       8       8       7
# 21      F     177      50          41       7       9       6
# 22      M     186      73          39      10       8       5
# 23      M     181      54          41       9       8      10
# 24      F     169      73          39       9       5       8

# %%
data.loc[12:18]
# Out:
#    gender  height  weight  shoes_size  score1  score2  score3
# 12      M     176      57          45       6       5       5
# 13      F     167      45          40       6       9       9
# 14      F     172      63          40       8      10       9
# 15      M     175      70          42      10       5       7
# 16      F     165      64          45       6      10       8
# 17      M     174      50          38       7       9       5
# 18      M     161      74          38       6       5       9

# %%
data.iloc[0:6, 0:4]
# Out:
#    gender  height  weight  shoes_size
# 12      M     176      57          45
# 13      F     167      45          40
# 14      F     172      63          40
# 15      M     175      70          42
# 16      F     165      64          45
# 17      M     174      50          38

# %%
data.describe()
# Out:
#            height     weight  shoes_size     score1     score2     score3
# count   13.000000  13.000000   13.000000  13.000000  13.000000  13.000000
# mean   174.384615  61.076923   40.538462   7.615385   7.538462   7.153846
# std      8.109033  10.242571    2.295481   1.502135   1.941451   1.818706
# min    161.000000  45.000000   38.000000   6.000000   5.000000   5.000000
# 25%    169.000000  52.000000   39.000000   6.000000   5.000000   5.000000
# 50%    174.000000  63.000000   40.000000   7.000000   8.000000   7.000000
# 75%    177.000000  70.000000   41.000000   9.000000   9.000000   9.000000
# max    190.000000  74.000000   45.000000  10.000000  10.000000  10.000000

# %%
data.describe()["score3"]["75%"]
# Out:
# 9.0

# %%
data["weight"].std()
# Out:
# 10.242570791078595

# %%
data["shoes_size"].max()
# Out:
# 45

# %%
import seaborn as sns

# %%
data
# Out:
#    gender  height  weight  shoes_size  score1  score2  score3
# 12      M     176      57          45       6       5       5
# 13      F     167      45          40       6       9       9
# 14      F     172      63          40       8      10       9
# 15      M     175      70          42      10       5       7
# 16      F     165      64          45       6      10       8
# 17      M     174      50          38       7       9       5
# 18      M     161      74          38       6       5       9
# 19      F     174      69          40       7       7       5
# 20      F     190      52          39       8       8       7
# 21      F     177      50          41       7       9       6
# 22      M     186      73          39      10       8       5
# 23      M     181      54          41       9       8      10
# 24      F     169      73          39       9       5       8

# %%
sns.displot(data["height"],kde= True) #cara versi lama

# %%
sns.displot(x="height",data=data,kde=True) #cara terbaru, menggambarkan persebaran

# %%
sns.boxplot(y="height",x="gender", data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='height'>

# %%
sns.violinplot(x="height",data=data)
# Out:
# <AxesSubplot:xlabel='height'>

# %%
sns.violinplot(x="weight",y="gender",data=data)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='gender'>

# %%
sns.countplot(x="gender", data=data) #menggambarkan frekuensi
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
data.corr()
# Out:
#               height    weight  shoes_size    score1    score2    score3
# height      1.000000 -0.230147   -0.101591  0.553622  0.112787 -0.388581
# weight     -0.230147  1.000000   -0.086973  0.375806 -0.526090 -0.032003
# shoes_size -0.101591 -0.086973    1.000000 -0.249114  0.004315 -0.061419
# score1      0.553622  0.375806   -0.249114  1.000000 -0.180241 -0.007039
# score2      0.112787 -0.526090    0.004315 -0.180241  1.000000  0.116189
# score3     -0.388581 -0.032003   -0.061419 -0.007039  0.116189  1.000000

# %%
np.cov(data["height"], data["weight"])
# Out:
# array([[ 65.75641026, -19.11538462],
#        [-19.11538462, 104.91025641]])

# %%
np.corrcoef(data["height"],data["weight"].to_numpy())
# Out:
# array([[ 1.        , -0.23014684],
#        [-0.23014684,  1.        ]])

# %%
#scatterplot
sns.scatterplot(x="height",y="weight",data=data, hue="gender")
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>

# %%
sns.scatterplot(x="height",y="weight",data=data, size="score1", hue="gender")
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>

# %%
sns.pairplot(data=data, hue="gender")

# %%
sns.jointplot(x="weight", y="shoes_size", data=data, hue="gender")
