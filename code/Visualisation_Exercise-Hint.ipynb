# %% [markdown]
# # Visualization - Data Science Kaggle Survey

# %% [markdown]
# In this notebook you will work on your visualisation skills. In the repo you will find a dataset from Kaggle. Every year, Kaggle conducts a survey on the topic of Data Science and Machine Learning. An invitation to participate in the survey is sent out to the entire Kaggle community. The survey is also promoted on the Kaggle website and Kaggle Twitter channel. The 2020 survey results were used as data for a Kaggle competition held at the end of the year. When evaluating the submissions, particular attention was paid to originality, a good structure/narrative and, last but not least **informative and appealing visualisations**.
#
# The survey contained 35 questions, most of which were multiple-choice. These questions allowed either one or more selected answers. Responses to multiple-choice questions where only a single choice could be selected were recorded in individual columns. Responses to multiple selection questions (multiple choices can be selected) were split into multiple columns (with one column per answer choice).
#
# Since this kind of data structure requires a lot of preprocessing before the visualization part can even begin, we decided to make the task a little easier.
# The dataset [kaggle_survey_dataset_small.csv](kaggle_survey_dataset_small.csv) that you will use for the following exercise contains only the questions whose responses where collected in a single column.
# If you need further information about the [methodology](kaggle_survey_2020_methodology.pdf) of the survey or the [questions](kaggle_survey_2020_answer_choices.pdf) and their possible answer options you will find two PDF-files with additional information in this repo.

# %% [markdown]
# ## Your Task
#
# Let's imagine the following scenario:
#
# You got a new dataset from one of your stakeholders. Addintionally to the dataset you received an email with a couple of very specific questions your stakeholder is interested in.
# Your task for this exercise is to create plots that clearly visualise the answers to your stakeholder's questions.
#
# You will find your stakeholder's questions further down in the notebook. To help you get started and get an overview over the data we prepared a list of all the questions, which are still included in the shortened dataset:
#
#
# * **Q1**: What is your age (# years)?
# * **Q2**: What is your gender?
# * **Q3**: In which country do you currently reside?
# * **Q4**: What is the highest level of formal education that you have attained or plan to attain within the next 2 years?
# * **Q5**: Select the title most similar to your current role (or most recent title if retired).
# * **Q6**: For how many years have you been writing code and/or programming?
# * **Q8**: What programming language would you recommend an aspiring data scientist to learn first?
# * **Q11**: What type of computing platform do you use most often for your data science projects?
# * **Q13**: Approximately how many times have you used a TPU (tensor processing unit)?
# * **Q15**: For how many years have you used machine learning methods?
# * **Q20**: What is the size of the company where you are employed?
# * **Q21**: Approximately how many individuals are responsible for data science workloads at your place ofbusiness?
# * **Q22**: Does your current employer incorporate machine learning methods into their business?
# * **Q24**: What is your current yearly compensation (approximate \$USD)?
# * **Q25**: Approximately how much money have you (or your team) spent on machine learning and/or cloudcomputing services at home (or at work) in the past 5 years (approximate \$USD)?
# * **Q30**: Which of the following big data products (relational database, data warehouse, data lake, or similar)do you use most often?
# * **Q32**: Which of the following business intelligence tools do you use most often?
# * **Q38**: What is the primary tool that you use at work or school to analyze data? (Include text response)

# %% [markdown]
# ## Setup and Import
#
# As always, the first step is to import the necessary libraries and the data...

# %%
# Import packages
import pandas as pd

# %%
# Import dataframe
df = pd.read_csv("kaggle_survey_dataset_small.csv", index_col= 0)
# delete the first row, index 0 and axis 0
df.drop(___, axis= ___, inplace=_____)
# Use head to take a look at the data
df.____()
# Out:
#       Q1   Q2                        Q3                 Q4                 Q5  \
# 1  35-39  Man                  Colombia    Doctoral degree            Student
# 2  30-34  Man  United States of America    Master’s degree      Data Engineer
# 3  35-39  Man                 Argentina  Bachelor’s degree  Software Engineer
# 4  30-34  Man  United States of America    Master’s degree     Data Scientist
# 5  30-34  Man                     Japan    Master’s degree  Software Engineer
#
#             Q6      Q8                                                Q11  \
# 1   5-10 years  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2   5-10 years  Python                      A personal computer or laptop
# 3  10-20 years       R                      A personal computer or laptop
# 4   5-10 years  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 5    3-5 years  Python                                                NaN
#
# ...

# %% [markdown]
# ## Getting to Know the Data
#
# Before you can start visualizing, you should get an overview of the data. Is the format of the data suitable for visualization or do you need to adjust something here and there?

# %%
# Examine the usual suspects: head, tail, unique values etc. 
print(df.____) # use method info
print(df.____) # print columns
print(df[____].____) # print column Q1 unique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20036 entries, 1 to 20036
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20036 non-null  int64
#  1   Q1          20036 non-null  object
#  2   Q2          20036 non-null  object
#  3   Q3          20036 non-null  object
#  4   Q4          19569 non-null  object
#  5   Q5          19277 non-null  object
#  6   Q6          19120 non-null  object
#  7   Q8          17821 non-null  object
#  8   Q11         17029 non-null  object
#  9   Q13         16780 non-null  object
#  10  Q15         16374 non-null  object
#  11  Q20         11403 non-null  object
#  12  Q21         11282 non-null  object
#  13  Q22         11130 non-null  object
#  14  Q24         10729 non-null  object
#  15  Q25         10570 non-null  object
#  16  Q30         3513 non-null   object
#  17  Q32         1498 non-null   object
#  18  Q38         13290 non-null  object
# ...

# %%
#subset the columns only for topics related tio machine learning
ML = df[[____]] # columns "Q1", "Q2", "Q15", "Q22", "Q24", "Q25"
ML._____ # Print head()
# Out:
#       Q1   Q2                                    Q15  \
# 1  35-39  Man                              1-2 years
# 2  30-34  Man                              1-2 years
# 3  35-39  Man  I do not use machine learning methods
# 4  30-34  Man                              3-4 years
# 5  30-34  Man                                    NaN
#
#                                                  Q22              Q24  \
# 1                                                NaN              NaN
# 2  We have well established ML methods (i.e., mod...  100,000-124,999
# 3                      No (we do not use ML methods)    15,000-19,999
# 4  We have well established ML methods (i.e., mod...  125,000-149,999
# 5                                                NaN              NaN
#
#                        Q25
# 1                      NaN
# 2  $100,000 or more ($USD)
# 3                $0 ($USD)
# 4          $10,000-$99,999
# 5                      NaN

# %%
# fill the missing values with unknown
ML.____("unknown", inplace=True) # using fillna

# %%
ML.head()
# Out:
#       Q1   Q2                                    Q15  \
# 1  35-39  Man                              1-2 years
# 2  30-34  Man                              1-2 years
# 3  35-39  Man  I do not use machine learning methods
# 4  30-34  Man                              3-4 years
# 5  30-34  Man                                unknown
#
#                                                  Q22              Q24  \
# 1                                            unknown          unknown
# 2  We have well established ML methods (i.e., mod...  100,000-124,999
# 3                      No (we do not use ML methods)    15,000-19,999
# 4  We have well established ML methods (i.e., mod...  125,000-149,999
# 5                                            unknown          unknown
#
#                        Q25
# 1                  unknown
# 2  $100,000 or more ($USD)
# 3                $0 ($USD)
# 4          $10,000-$99,999
# 5                  unknown

# %% [markdown]
# ## Visualisations

# %% [markdown]
# Now that you have a feel for the data, let's start to work on the tasks of your stakeholder.

# %%
# Your code here
import seaborn as sns
import matplotlib.pyplot as plt
#age = ML.groupby("Q1").count()
plt._____(figsize=(8,4)) # use plt.figure
sns._____(data = ML[1:], x = ___ ) # plot histplot dan x = "Q1"
# Out:
# <AxesSubplot:xlabel='Q1', ylabel='Count'>

# %%
# gender
plt._____(figsize=(12, 5)) # Use plt-figure
sns._____(data = ML, x = "Q2" ) # Use histplot
# Out:
# <AxesSubplot:xlabel='Q2', ylabel='Count'>

# %%
fig, ax = plt._____(figsize = (12, 5)) # Gunakan subplots

ax.hist(ML["Q1"], histtype= "step", label = "Age")
#ax.hist(ML["Q2"])

plt.show()

# %% [markdown]
# ### 1. Plot
#
# Your stakeholder wants to have a visual comparison between the yearly compensation of people who work as Data Scientists, Data Analysts, and Data Engineers.

# %%
df["Q5"]._____ # use method unique()
# Out:
# array(['Student', 'Data Engineer', 'Software Engineer', 'Data Scientist',
#        'Data Analyst', 'Research Scientist', 'Other',
#        'Currently not employed', 'Statistician',
#        'Product/Project Manager', 'Machine Learning Engineer', nan,
#        'Business Analyst', 'DBA/Database Engineer'], dtype=object)

# %%
comp = df[["Q5", "Q24"]] #subset Q5 and Q24
comp = comp[(comp["Q5"] == ____) | (comp["Q5"] == ___) | (comp["Q5"] == ___)] # subset Data Engineer/Data Scintist dan Data Analyst
comp.fillna("unknown", inplace=True)
comp.head()
# Out:
#                 Q5              Q24
# 2    Data Engineer  100,000-124,999
# 4   Data Scientist  125,000-149,999
# 6     Data Analyst          unknown
# 9   Data Scientist    70,000-79,999
# 14   Data Engineer    90,000-99,999

# %%
#c = comp.groupby("Q5").count()
#c["Q24"].plot.pie(autopct="%.1f%%")

# %%
plt.figure(figsize=(20,5))
sns.histplot(data = comp, x = "Q24", hue= "Q5" )
plt.xticks(rotation=70)
plt.tight_layout()
plt.xlabel("Compensation per Year")
# Out:
# Text(0.5, -50.11630524324657, 'Compensation per Year')

# %% [markdown]
# ### 2. Plot
#
# Your stakeholder wants to know the gender distribution in the countries where most people participated in the survey. He is interested in the top 10 countries.
# And in the top 10 countries with the most number of female survey participants.

# %%
import pandas as pd

# Import dataframe
df = pd._____("kaggle_survey_dataset_small.csv", index_col= 0) # read_csv
# delete the first row 
df.drop(0, axis= 0, inplace=True)

# subset only required variables (Q3 = countries, and Q2 = gender)
df1 = df[["Q3", "Q2"]]

# one-hot-encoding the "Q2"
g_dummy = pd.____(df1["Q2"]) # use one hot encoding get_dummies
# concatenate g_dummy to df1
df_dummy = pd.concat([df1, g_dummy], axis=1)

# groupby the country and sort by women, to get the 10 countries with most women participation in survey
woman_sort = df_dummy._____("Q3").count().sort_values("Woman", ascending=False) # Use group by
# get only 10 countries
df_women_sort = woman_sort.loc["India":"Turkey"]
# delete the "Other" from country list
df_women_sort.drop("Other", axis=0, inplace=True)
df_women_sort._____inplace= True) # reset index
df_women_sort

#import plotly
import plotly.express as px

# creating simple pie plot with plotly
fig = _____(df_women_sort, values = "Woman", names= "Q3", title = "Female Participations") # use px.pie
fig.show()

# %%
import plotly.express as px
fig = px.bar(df_women_sort, x = "Q3", y = "Woman" )


fig.show()

# %%
df_women_sort["Woman"].plot.pie(autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='Woman'>

# %% [markdown]
# ### 3. Plot
#
# According to the study, aspiring Data Scientists are most often recommended to learn Python. Since Python is widely known in the stakeholder's company, he would like to know which language is most recommended after Python. He also suspects that there might be a difference in recommended languages depending on the title of the survey participant's current role and he wants to know what people with the job title "Data Scientist", "Data Analyst", and "Data Engineer" recommend. Can you confirm or reject his assumption with a/some suitable plot(s)?

# %%
# Your code here
df2 = df[["Q8", "Q5"]]
df2.dropna(inplace=True)
df2 = df2[(df2["Q5"] == "Data Engineer") | (df2["Q5"] == "Data Scientist") | (df2["Q5"] == "Data Analyst")]

pop_lang = df2.groupby(["Q8"]).count().sort_values("Q5", ascending = False)
pop_lang.plot()
# Out:
# <AxesSubplot:xlabel='Q8'>

# %%
df2
# Out:
#            Q8              Q5
# 2      Python   Data Engineer
# 4      Python  Data Scientist
# 6      Python    Data Analyst
# 9      Python  Data Scientist
# 14     Python   Data Engineer
# ...       ...             ...
# 20005  Python  Data Scientist
# 20006  Python  Data Scientist
# 20012     SQL    Data Analyst
# 20019  MATLAB  Data Scientist
# 20029  Python    Data Analyst
#
# [4377 rows x 2 columns]

# %%
df_eng = df2[df2["Q5"] == "Data Engineer"]
df_scien = df2[df2["Q5"] == "Data Scientist"]
df_anlyt = df2[df2["Q5"] == "Data Analyst"]

# %%
df_eng_group = df_eng.groupby("Q8").count()
df_eng_group.plot(kind = "bar")
plt.xlabel("Data Engineer")
# Out:
# Text(0.5, 0, 'Data Engineer')

# %%
df_scien_group = df_scien.groupby("Q8").count()
df_scien_group.plot(kind = "bar")
plt.xlabel("Data Science")
# Out:
# Text(0.5, 0, 'Data Science')

# %%
df_anlyt_group = df_anlyt.groupby("Q8").count()
df_anlyt_group.plot(kind = "bar")
plt.xlabel("Data Analyst")
# Out:
# Text(0.5, 0, 'Data Analyst')
